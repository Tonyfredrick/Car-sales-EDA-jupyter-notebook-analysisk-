# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib. pylab as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv('car sales.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
df.shape
# Out:
# (157, 16)

# %%
df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %%
df.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
df= df[['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
       #'Vehicle_type', 
       'Price_in_thousands', 'Engine_size', 'Horsepower',
       'Wheelbase', #'Width', 'Length', 'Curb_weight', 
       'Fuel_capacity',
       'Fuel_efficiency', #'Latest_Launch', 
       'Power_perf_factor']].copy()

# %%
df.shape
# Out:
# (157, 11)

# %%
df.shape
# Out:
# (157, 11)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# Length: 157, dtype: bool

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Power_perf_factor      float64
# dtype: object

# %%
df.rename(columns={'__year_resale_value' : 'year_resale_value'})
# Out:
#     Manufacturer    Model  Sales_in_thousands  year_resale_value  \
# 0          Acura  Integra              16.919             16.360
# 1          Acura       TL              39.384             19.875
# 2          Acura       CL              14.114             18.225
# 3          Acura       RL               8.588             29.725
# 4           Audi       A4              20.397             22.255
# ..           ...      ...                 ...                ...
# 152        Volvo      V40               3.545                NaN
# 153        Volvo      S70              15.245                NaN
# 154        Volvo      V70              17.531                NaN
# 155        Volvo      C70               3.493                NaN
# 156        Volvo      S80              18.969                NaN
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Fuel_capacity  \
# 0                 21.50          1.8       140.0      101.2           13.2
# ...

# %%
df.rename(columns={'Fuel_capacity':'fuel_capacity'})
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  fuel_capacity  \
# 0                 21.50          1.8       140.0      101.2           13.2
# ...

# %%
df.rename(columns={'fuel_capacity' :'Fuel_capacity'})
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Fuel_capacity  \
# 0                 21.50          1.8       140.0      101.2           13.2
# ...

# %%
df.isna().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Fuel_capacity           1
# Fuel_efficiency         3
# Power_perf_factor       2
# dtype: int64

# %%
df['Power_perf_factor'].fillna(df['Power_perf_factor'].mean(), inplace =True)

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales_in_thousands, __year_resale_value, Price_in_thousands, Engine_size, Horsepower, Wheelbase, Fuel_capacity, Fuel_efficiency, Power_perf_factor]
# Index: []

# %%
df.loc[df.duplicated(subset=['Power_perf_factor'])]
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 33      Chrysler  Town & Country              53.480                19.54
# 114     Plymouth            Neon              32.734                 7.75
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Fuel_capacity  \
# 33                  NaN          NaN         NaN        NaN            NaN
# 114               12.64          2.0       132.0      105.0           12.5
#
#      Fuel_efficiency  Power_perf_factor
# 33               NaN          77.043591
# 114             29.0          52.084899

# %%
df.query("Power_perf_factor == "52"")
# Out:
#   Cell In[35], line 1
#     df.query("Power_perf_factor == "52"")
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df.isna().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Fuel_capacity           1
# Fuel_efficiency         3
# Power_perf_factor       0
# dtype: int64

# %%
df['Fuel_capacity'].fillna(df['Fuel_capacity'].mean(), inplace=True)

# %%
df['Fuel_efficiency'].fillna(df['Fuel_efficiency'].mean(),inplace=True)

# %%
df['Wheelbase'].fillna(df['Wheelbase'].mean(),inplace =True)

# %%
df['Horsepower'].fillna(df['Horsepower'].mean(),inplace=True)

# %%
df['Engine_size'].fillna(df['Engine_size'].mean(),inplace=True)

# %%
df['Price_in_thousands'].fillna(df['Price_in_thousands'] .mean(), inplace=True)

# %%
df['__year_resale_value'].fillna(df['__year_resale_value'].mean(), inplace=True)

# %%
df.head(20)
# Out:
#    Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 0         Acura      Integra              16.919            16.360000
# 1         Acura           TL              39.384            19.875000
# 2         Acura           CL              14.114            18.225000
# 3         Acura           RL               8.588            29.725000
# 4          Audi           A4              20.397            22.255000
# 5          Audi           A6              18.780            23.555000
# 6          Audi           A8               1.380            39.000000
# 7           BMW         323i              19.747            18.072975
# 8           BMW         328i               9.231            28.675000
# 9           BMW         528i              17.527            36.125000
# 10        Buick      Century              91.561            12.475000
# 11        Buick        Regal              39.350            13.740000
# ...

# %%
df.isna().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Fuel_capacity          0
# Fuel_efficiency        0
# Power_perf_factor      0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# Length: 157, dtype: bool

# %%
df['Sales_in_thousands'].value_counts()
# Out:
# 16.919     1
# 1.112      1
# 42.643     1
# 88.094     1
# 79.853     1
#           ..
# 155.787    1
# 125.338    1
# 220.650    1
# 540.561    1
# 18.969     1
# Name: Sales_in_thousands, Length: 157, dtype: int64

# %%
df['Manufacturer'].value_counts()
# Out:
# Dodge         11
# Ford          11
# Toyota         9
# Chevrolet      9
# Mercedes-B     9
# Mitsubishi     7
# Nissan         7
# Chrysler       7
# Volvo          6
# Oldsmobile     6
# Lexus          6
# Mercury        6
# Pontiac        6
# Volkswagen     6
# Saturn         5
# Cadillac       5
# Honda          5
# Plymouth       4
# Acura          4
# Buick          4
# Audi           3
# Jeep           3
# Porsche        3
# Hyundai        3
# BMW            3
# Lincoln        3
# Saab           2
# Subaru         2
# Jaguar         1
# Infiniti       1
# Name: Manufacturer, dtype: int64

# %%
ax = df['Manufacturer'].value_counts()\
  .head(10) \
  .plot(kind='bar',title='List of most Available cars')
ax.set_xlabel('Name of cars')
ax.set_ylabel('Count of cars')
# Out:
# Text(0, 0.5, 'Count of cars')

# %%
df['Horsepower'].plot(kind='hist',bins=20,title='cars Horsepower')
# Out:
# <Axes: title={'center': 'cars Horsepower'}, ylabel='Frequency'>

# %%
df['Horsepower'].plot(kind='hist',bins=20,title='cars Horsepower')
# Out:
# <Axes: title={'center': 'cars Horsepower'}, ylabel='Frequency'>

# %%
df.plot(kind='scatter',
       x='Fuel_capacity',
       y='Wheelbase',
       title='Fuel_capacity vs Wheelbase')
plt.show()

# %%
sns.scatterplot(x='Fuel_capacity',
       y='Wheelbase',
       hue='Manufacturer',        
       data=df)
# Out:
# <Axes: xlabel='Fuel_capacity', ylabel='Wheelbase'>
